# %%
import utils
import cmprxn

# %%
img_utils_obj = utils.img_utils("data/honda.jpg")

# %%
my_array = img_utils_obj.reshape_img()

# %%
img_utils_obj.display_image()

# %%
my_array.shape
# Out:
# (115200, 3)

# %%
cmprxr_obj = cmprxn.k_cluster(array=my_array,k=3, algo_type="means")

# %%
cmprxr_obj.run()

# %%
img_utils_obj.rebuild_compressed_image(cmprxr_obj)
